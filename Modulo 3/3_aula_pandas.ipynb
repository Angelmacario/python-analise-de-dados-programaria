# %% [markdown]
# # Uso da biblioteca pandas
#
# - df.head()      # Para ver as 5 primeiras linhas
# - df.tail()      # Para ver as 5 últimas
# - df.info()      # Para ver estrutura e tipos das colunas
# - df.describe()  # Para estatísticas das colunas numéricas
# - dados.shape    # é um atributo e não uma função - mostra a qtd de linhas e colunas
# - len(dados)     # mostra a quantidade total
# - dados.columns  # mostra as colunas da tabelas
# - dados['coluna'].value_counts() #mostra a qnt de cada opção da coluna
#
# - Cookbook do pandas: https://pandas.pydata.org/docs/user_guide/cookbook.html

# %%
import pandas as pd

# %%
#fazer a leitura do excel
dados = pd.read_csv(
    'C:/Users/Ge e Rafa/OneDrive/Documentos/Estudos/PYTHON/python-analise-de-dados-programaria/Modulo 3/licitacoes.csv',
    encoding='latin1',
    sep=';'
)

# %%
#mostra os dados da tabela
dados.head()
# Out:
#    Número Licitação  Código UG                                       Nome UG  \
# 0             12016     160438     COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA
# 1             12017     160203       2º BATALHAO DE ENGENHARIA DE CONSTRUCAO
# 2             12017     193002  DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS
# 3             12018     925135              BANCO CENTRAL DO BRASIL - RECIFE
# 4             12018     110101     GABINETE DA VICE-PRESIDENCIA DA REPUBLICA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                       -99    Pregão - Registro de Preço  80871182401201629
# 1                         3                  Concorrência  64040053530201713
# 2                         2              Tomada de Preços  59400003079201636
# 3                         6         Dispensa de Licitação             148097
# 4                         7  Inexigibilidade de Licitação  00300000433201818
#
# ...

# %%
dados.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %%
dados[dados['Situação Licitação'] == 'Encerrado']
# Out:
#        Número Licitação  Código UG  \
# 3                 12018     925135
# 16                12018     130129
# 18                12018     135097
# 19                12018     152140
# 24                12018     153092
# ...                 ...        ...
# 15327         907662018     926130
# 15328         907732018     926130
# 15329         908252018     926130
# 15333         990922018     158139
# 15334         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 16       SUPERINT.REG.DE DESENV.DA LAV.CACAUEIRA/MT                         6
# 18                                     EMBRAPA CAFE                         7
# 19                    IFB - CAMPUS TAGUATINGA NORTE                         6
# 24                       BIBLIOTECA CENTRAL DA UFPE                         6
# ...

# %%
dados['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %%
dados.head() # Para ver as 5 primeiras linhas
# Out:
#    Número Licitação  Código UG                                       Nome UG  \
# 0             12016     160438     COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA
# 1             12017     160203       2º BATALHAO DE ENGENHARIA DE CONSTRUCAO
# 2             12017     193002  DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS
# 3             12018     925135              BANCO CENTRAL DO BRASIL - RECIFE
# 4             12018     110101     GABINETE DA VICE-PRESIDENCIA DA REPUBLICA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                       -99    Pregão - Registro de Preço  80871182401201629
# 1                         3                  Concorrência  64040053530201713
# 2                         2              Tomada de Preços  59400003079201636
# 3                         6         Dispensa de Licitação             148097
# 4                         7  Inexigibilidade de Licitação  00300000433201818
#
# ...

# %%
dados.tail()  # Para ver as 5 últimas
# Out:
#        Número Licitação  Código UG                                    Nome UG  \
# 15331         920182018     135023                              EMBRAPA/CNPAB
# 15332         924192017     158274  INST.FED. FLUMINENSE/CAMPUS CAMPOS-CENTRO
# 15333         990922018     158139   INST.FED.DE EDUC.,CIENC.E TEC.FLUMINENSE
# 15334         996252018     153035  UNIVERSIDADE FEDERAL DO TRIANGULO MINEIRO
# 15335         996252018     153035  UNIVERSIDADE FEDERAL DO TRIANGULO MINEIRO
#
#        Código Modalidade Compra             Modalidade Compra  \
# 15331                       -99    Pregão - Registro de Preço
# 15332                         6         Dispensa de Licitação
# 15333                         6         Dispensa de Licitação
# 15334                         6         Dispensa de Licitação
# 15335                         7  Inexigibilidade de Licitação
#
#          Número Processo                                             Objeto  \
# ...

# %%
dados.info()      # Para ver estrutura e tipos das colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
dados.shape   # é um atributo e não uma função - mostra a qtd de linhas e colunas
# Out:
# (15336, 17)

# %%
dados.describe()  # Para estatísticas das colunas numéricas
# Out:
#        Número Licitação      Código UG  Código Modalidade Compra  \
# count      1.533600e+04   15336.000000              15336.000000
# mean       1.187265e+07  211458.782016                 -5.994327
# std        7.223749e+07  148542.739765                 33.291265
# min        1.201600e+04   30100.000000                -99.000000
# 25%        2.420180e+05  153079.000000                  6.000000
# 50%        6.720180e+05  160108.000000                  6.000000
# 75%        1.652018e+06  200334.000000                  6.000000
# max        9.962520e+08  926524.000000                 20.000000
#
#        Código Órgão Superior  Código Órgão
# count           15336.000000  15336.000000
# mean            36443.087898  35072.975548
# std             13783.932637  13538.294712
# min              3000.000000   3000.000000
# 25%             26000.000000  26233.000000
# 50%             30000.000000  26439.000000
# 75%             52000.000000  52111.000000
# ...

# %%
len(dados) #mostra a quantidade total
# Out:
# 15336

# %%
dados.columns #mostra as colunas da tabelas
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %% [markdown]
# ## Aula 3.5 Aprendendo mais coisas

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dados.groupby('GENERO')['ID'].nunique()
#
# File c:\Users\Ge e Rafa\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...
